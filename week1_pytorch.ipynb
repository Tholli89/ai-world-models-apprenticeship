# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
print("PyTorch ready!")
# Out:
# PyTorch ready!

# %%
# Basic tensor
x = torch.tensor([1.0, 2.0, 3.0])
y = torch.tensor([2.0, 4.0, 6.0])
print("x:", x)
print("y:", y)
print("x * 2:", x * 2)
# Out:
# x: tensor([1., 2., 3.])
# y: tensor([2., 4., 6.])
# x * 2: tensor([2., 4., 6.])

# %%
# Toy data
X = torch.tensor([[1.0], [2.0], [3.0], [4.0]])
y = torch.tensor([[2.0], [4.0], [6.0], [8.0]])

model = nn.Linear(1, 1)  # input 1, output 1
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
loss_fn = nn.MSELoss()

losses = []
for epoch in range(200):
    pred = model(X)
    loss = loss_fn(pred, y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    losses.append(loss.item())
    if epoch % 50 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item():.4f}")

print("Final weight:", model.weight.item())  # ~2.0
plt.plot(losses);
plt.title("Loss Curve");
# Out:
# Epoch 0, Loss: 32.2595
# Epoch 50, Loss: 0.0131
# Epoch 100, Loss: 0.0097
# Epoch 150, Loss: 0.0072
# Final weight: 2.0607879161834717

# %%
test_x = torch.tensor([[5.0]])
print("Predict x=5:", model(test_x).item())  # ~10
# Out:
# Predict x=100: 205.9000701904297
